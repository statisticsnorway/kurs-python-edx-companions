# %% [markdown]
# ### Google!

# %% [markdown]
# https://www.google.com/search?q=pandas+dataframe

# %% [markdown]
# ### Stack overflow FTW

# %% [markdown]
# Hvor spesifikk er du, og hvor mange begreper kan du?\
# https://www.google.com/search?q=pandas+concatenate+dataframes+with+category+columns

# %% [markdown]
# ### Kvaliteten på pakkens egen dokumentasjon varierer :/

# %% [markdown]
# Pandas sin er <u>svært god</u>\
# https://pandas.pydata.org/pandas-docs/stable/user_guide/index.html

# %% [markdown]
# Andre kan hende kun har "readme" på github?\
# https://github.com/seatgeek/fuzzywuzzy

# %% [markdown]
# ### Rekkefølge på lesing? Ikke alltid fra topp til bunn?

# %% [markdown]
# ![image.png](attachment:8b8cbbef-5ba2-489b-be16-4ed9b7b29a8e.png)

# %% [markdown]
# ![image.png](attachment:40fe997b-dc25-4eb8-92f2-99a14d9979e2.png)
